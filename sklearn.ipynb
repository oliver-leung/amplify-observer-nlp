# %%
# Update and import packages
# !pip install -Uqr requirements.txt
# !/bin/bash ./local_mode_setup.sh

# Basic packages
import importlib
from time import time
from pathlib import Path
from progress.bar import Bar
import json
import re
import io
from bs4 import BeautifulSoup

# Data science/NLP packages
import numpy as np
import pandas as pd
pd.set_option("display.max_colwidth", None)

# AWS packages
import awswrangler as wr
import sagemaker
from sagemaker.sklearn import SKLearn
from sagemaker.predictor import Predictor
import boto3

# Local modules
import model
import train
for m in [model, train]:
    importlib.reload(m)

from model import VectorSimilarity, get_fitted_model
from train import combine_dfs
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# awscli 1.19.100 requires botocore==1.20.100, but you have botocore 1.21.11 which is incompatible.
# awscli 1.19.100 requires s3transfer<0.5.0,>=0.4.0, but you have s3transfer 0.5.0 which is incompatible.
# aiobotocore 1.3.0 requires botocore<1.20.50,>=1.20.49, but you have botocore 1.21.11 which is incompatible.

# %%
# Sanity checks on VectorSimilarity
X = np.array(
    [[0, 1],
     [1, 0],
     [-1, 0]])
y = np.array(['a', 'b', 'c'])

estimator = VectorSimilarity()
estimator = estimator.fit(X, y)
pred, score = estimator.predict(np.array([1, 2]).reshape(1, -1))
# Out:
# [['a' 'b' 'c']]
# [[ 2.  1. -1.]]
# Prediction took 0.001055002212524414 seconds

# %%
# Basic pipeline setup
basic_corpus = [
    'Bees like to make honey',
    'Bears like to eat honey',
    'Bees don\'t like bears',
    'Humans are walking around the park'
]
basic_labels = ['a', 'b', 'c', 'd']

pipe = get_fitted_model(basic_corpus, basic_labels, lemmatize='custom')
pred, score = pipe.predict(basic_corpus)
# Out:
# Training model...
# Took 1.6626145839691162 seconds
# [['a' 'c' 'b' 'd']
#  ['b' 'c' 'a' 'd']
#  ['c' 'b' 'a' 'd']
#  ['d' 'c' 'b' 'a']]
# [[1.         0.27710268 0.27710268 0.        ]
#  [1.         0.27710268 0.27710268 0.        ]
#  [1.         0.27710268 0.27710268 0.        ]
#  [1.         0.         0.         0.        ]]
# Prediction took 0.0006358623504638672 seconds
# /opt/conda/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:391: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['make'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
# File helper functions
def list_data_objs():
    secret_name = "SageMakerS3Access"
    region_name = "us-west-2"
    bucket_name = 'amplifyobserverinsights-aoinsightslandingbucket29-5vcr471d4nm5'
    bucket_subfolder = 'data/issues/'
    
#     secrets = boto3.client(
#         service_name='secretsmanager',
#         region_name=region_name
#     )

#     secrets_response = secrets.get_secret_value(SecretId=secret_name)
#     secrets_dict = json.loads(secrets_response['SecretString'])
#     (access_key, secret_key), = secrets_dict.items()

    s3 = boto3.client('s3')
    data_objects = s3.list_objects_v2(Bucket=bucket_name, Prefix=bucket_subfolder)['Contents']
    data_obj_names = [key['Key'] for key in data_objects]
#     data_obj_names = [f"s3://{bucket_name}/{key['Key']}" for key in data_objects]
    
    return data_obj_names


def download_data(filename, data_obj_names):
    dfs = []
    s3 = boto3.client(
        's3',
    )
    
    with Bar(
        message='Downloading parquets',
        check_tty=False,
        hide_cursor=False,
        max=len(data_obj_names)
    ) as bar:

        for obj_name in data_obj_names:
#             df = wr.s3.read_csv(obj_name)
            obj = s3.get_object(Bucket='amplifyobserverinsights-aoinsightslandingbucket29-5vcr471d4nm5', Key=obj_name)
            df = pd.read_parquet(io.BytesIO(obj['Body'].read()))
            dfs.append(df)
            bar.next()

        bar.finish()
        
    df = combine_dfs(dfs)
    df.to_csv(filename)

    return df

def get_data(filename, force_redownload=False):
    start = time()
    data = Path(filename)
    
    if data.is_file() and not force_redownload:
        print('Deserializing data from', filename, '...')
        df = pd.read_csv(filename)
        
    else:
        data_obj_names = list_data_objs()
        df = download_data(filename, data_obj_names[1:]) # TODO: this is because list data objs is returning an empty thing
        
    print('Took', time() - start, 'seconds')    
    return df

# %%
# Data helper functions
def query_df(df, **kwargs):
    query = True
    for key, value in kwargs.items():
        query &= (df[key] == value)
        
    result = df[query]
    return result

# %%
# Download and compile parquets
df = get_data('training_data.csv', force_redownload=True)
# Out:
# Downloading parquets |################################| 18/18
# Took 2.2039387226104736 seconds

# %%
# Train model
corpus_col='title_body'
url_col = 'url'
title_col='title'
train_df = df

corpus = train_df[corpus_col]
labels = list(zip(train_df[url_col], train_df[title_col]))

pipe = get_fitted_model(corpus, labels, lemmatize='custom')
# Out:
# Training model...
# /opt/conda/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:391: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['make'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# Took 73.72894024848938 seconds

# %%
pw_mgr_query = ['AmplifySignIn component does not work with password managers or native browser autofill']
pred, score = pipe.predict(pw_mgr_query)

# %%
# Model stats
vocab = pipe['tfidfvectorizer'].get_feature_names()
print('Number of vocab words:', len(vocab))
repo_list = list(set(df['repo']))
print('Available repos:', repo_list)
small_words = [word for word in vocab if len(word) < 3]
print('Small words in vocab:\n', small_words)

# print(pipe[1]._labels)
# Out:
# Number of vocab words: 23750
# Available repos: ['amplify-ci-support', 'amplify-ios', 'amplify-adminui', 'aws-appsync-realtime-client-ios', 'amplify-android', 'amplify-cli', 'amplify-js-samples', 'amplify-codegen', 'community', 'aws-sdk-ios', 'amplify-console', 'docs', 'amplify-ui', 'aws-amplify.github.io', 'amplify-js', 'amplify-flutter', 'amplify-observer', 'aws-sdk-android']
# Small words in vocab:
#  ['ad', 'al', 'au', 'az', 'bk', 'ca', 'cc', 'cd', 'cf', 'ci', 'cm', 'cs', 'cu', 'cv', 'db', 'dm', 'dy', 'ec', 'ed', 'em', 'er', 'es', 'fo', 'gb', 'gc', 'gi', 'gm', 'hl', 'hr', 'hz', 'ic', 'id', 'io', 'ip', 'iv', 'ki', 'km', 'kv', 'l', 'lf', 'lm', 'mb', 'mi', 'os', 'pc', 'pe', 'po', 'pr', 'r', 's', 'sc', 'sd', 'si', 'sl', 'sm', 'sn', 'ss', 'ti', 'tl', 'tn', 'tt', 'vi', 'w', 'x', 'zu']

# %%
with open('vocab.txt', 'w') as f:
    f.write(str(vocab))

# %%
tokenizer = pipe[0].build_tokenizer()
print(tokenizer.custom)
token = tokenizer('walk walks talk talks talking talked')
print(token)

# %%
js_issue = query_df(js_df, number=8108)[corpus_col].item()
inspect_doc(pipe[0], js_issue)
get_weights(pipe[0], 'workarounds issued cognito pool', js_issue)

# %%
# Train SM estimator
train_data = 's3://amplifyobserverinsights-aoinsightslandingbucket29-5vcr471d4nm5/data/issues/'
sklearn_estimator = SKLearn(
    'train.py',
    role=sagemaker.get_execution_role(),
    instance_type='local',
    framework_version='0.23-1',
    hyperparameters = {'n-best': 10},
    dependencies=['.']
)
sklearn_estimator.fit({'train': train_data})
# Out:
# <<<<<<< local
# Creating 096xlv7tu0-algo-1-vff22 ...
# Creating 096xlv7tu0-algo-1-vff22 ... done
# Attaching to 096xlv7tu0-algo-1-vff22
# 096xlv7tu0-algo-1-vff22 | 2021-07-30 23:00:59,732 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 096xlv7tu0-algo-1-vff22 | 2021-07-30 23:00:59,735 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 096xlv7tu0-algo-1-vff22 | 2021-07-30 23:00:59,744 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 096xlv7tu0-algo-1-vff22 | 2021-07-30 23:00:59,940 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# 096xlv7tu0-algo-1-vff22 | /miniconda3/bin/python -m pip install -r requirements.txt
# 096xlv7tu0-algo-1-vff22 | Requirement already satisfied: pip in /miniconda3/lib/python3.7/site-packages (from -r requirements.txt (line 1)) (21.0.1)
# 096xlv7tu0-algo-1-vff22 | Collecting progress
# 096xlv7tu0-algo-1-vff22 |   Downloading progress-1.6.tar.gz (7.8 kB)
# 096xlv7tu0-algo-1-vff22 | Collecting awswrangler
# 096xlv7tu0-algo-1-vff22 |   Downloading awswrangler-2.10.0-py3-none-any.whl (184 kB)
#      |████████████████████████████████| 184 kB 8.1 MB/s eta 0:00:01
# 096xlv7tu0-algo-1-vff22 | Requirement already satisfied: boto3 in /miniconda3/lib/python3.7/site-packages (from -r requirements.txt (line 4)) (1.16.4)
# 096xlv7tu0-algo-1-vff22 | Requirement already satisfied: pandas in /miniconda3/lib/python3.7/site-packages (from -r requirements.txt (line 5)) (1.1.3)
# 096xlv7tu0-algo-1-vff22 | Requirement already satisfied: scikit-learn in /miniconda3/lib/python3.7/site-packages (from -r requirements.txt (line 6)) (0.23.2)
# 096xlv7tu0-algo-1-vff22 | Collecting markdown
# 096xlv7tu0-algo-1-vff22 |   Downloading Markdown-3.3.4-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 6.0 MB/s  eta 0:00:01
# 096xlv7tu0-algo-1-vff22 | Collecting bs4
# 096xlv7tu0-algo-1-vff22 |   Downloading bs4-0.0.1.tar.gz (1.1 kB)
# 096xlv7tu0-algo-1-vff22 | Collecting sagemaker
# 096xlv7tu0-algo-1-vff22 |   Downloading sagemaker-2.50.0.tar.gz (423 kB)
#      |████████████████████████████████| 423 kB 10.9 MB/s eta 0:00:01
# 096xlv7tu0-algo-1-vff22 | Requirement already satisfied: joblib in /miniconda3/lib/python3.7/site-packages (from -r requirements.txt (line 10)) (1.0.1)
# 096xlv7tu0-algo-1-vff22 | Collecting nltk
# 096xlv7tu0-algo-1-vff22 |   Downloading nltk-3.6.2-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 12.9 MB/s eta 0:00:01
# 096xlv7tu0-algo-1-vff22 | Collecting pyarrow<4.1.0,>=2.0.0
# 096xlv7tu0-algo-1-vff22 |   Downloading pyarrow-4.0.1-cp37-cp37m-manylinux2014_x86_64.whl (21.8 MB)
#      |████████████████████████████████| 21.8 MB 38.5 MB/s eta 0:00:01
# 096xlv7tu0-algo-1-vff22 | Collecting botocore<2.1.0,>=1.19.8
# 096xlv7tu0-algo-1-vff22 |   Downloading botocore-1.21.11-py3-none-any.whl (7.8 MB)
#      |████████████████████████████████| 7.8 MB 80.0 MB/s eta 0:00:01
# 096xlv7tu0-algo-1-vff22 | Collecting redshift-connector~=2.0.882
# 096xlv7tu0-algo-1-vff22 |   Downloading redshift_connector-2.0.883-py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 3.6 MB/s  eta 0:00:01
# 096xlv7tu0-algo-1-vff22 | Collecting openpyxl~=3.0.0
# 096xlv7tu0-algo-1-vff22 |   Downloading openpyxl-3.0.7-py2.py3-none-any.whl (243 kB)
#      |████████████████████████████████| 243 kB 93.5 MB/s eta 0:00:01
# 096xlv7tu0-algo-1-vff22 | Requirement already satisfied: numpy<2.1.0,>=1.18.0 in /miniconda3/lib/python3.7/site-packages (from awswrangler->-r requirements.txt (line 3)) (1.19.2)
# 096xlv7tu0-algo-1-vff22 | Collecting boto3
# 096xlv7tu0-algo-1-vff22 |   Downloading boto3-1.18.11-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 89.7 MB/s eta 0:00:01
# 096xlv7tu0-algo-1-vff22 | Collecting pymysql<1.1.0,>=0.9.0
# 096xlv7tu0-algo-1-vff22 |   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 3.5 MB/s  eta 0:00:01
# 096xlv7tu0-algo-1-vff22 | Collecting pg8000<1.21.0,>=1.16.0
# 096xlv7tu0-algo-1-vff22 |   Downloading pg8000-1.20.0-py3-none-any.whl (34 kB)
# 096xlv7tu0-algo-1-vff22 | Collecting s3transfer<0.6.0,>=0.5.0
# 096xlv7tu0-algo-1-vff22 |   Downloading s3transfer-0.5.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 14.0 MB/s eta 0:00:01
# 096xlv7tu0-algo-1-vff22 | Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /miniconda3/lib/python3.7/site-packages (from boto3->-r requirements.txt (line 4)) (0.10.0)
# 096xlv7tu0-algo-1-vff22 | Requirement already satisfied: pytz>=2017.2 in /miniconda3/lib/python3.7/site-packages (from pandas->-r requirements.txt (line 5)) (2021.1)
# 096xlv7tu0-algo-1-vff22 | Requirement already satisfied: python-dateutil>=2.7.3 in /miniconda3/lib/python3.7/site-packages (from pandas->-r requirements.txt (line 5)) (2.8.1)
# 096xlv7tu0-algo-1-vff22 | Requirement already satisfied: urllib3<1.27,>=1.25.4 in /miniconda3/lib/python3.7/site-packages (from botocore<2.1.0,>=1.19.8->awswrangler->-r requirements.txt (line 3)) (1.25.11)
# 096xlv7tu0-algo-1-vff22 | Collecting et-xmlfile
# 096xlv7tu0-algo-1-vff22 |   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# 096xlv7tu0-algo-1-vff22 | Collecting scramp>=1.4.0
# 096xlv7tu0-algo-1-vff22 |   Downloading scramp-1.4.0-py3-none-any.whl (8.4 kB)
# 096xlv7tu0-algo-1-vff22 | Requirement already satisfied: six>=1.5 in /miniconda3/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas->-r requirements.txt (line 5)) (1.15.0)
# 096xlv7tu0-algo-1-vff22 | Collecting beautifulsoup4<5.0.0,>=4.7.0
# 096xlv7tu0-algo-1-vff22 |   Downloading beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 110.2 MB/s eta 0:00:01
# 096xlv7tu0-algo-1-vff22 | Requirement already satisfied: requests<2.25.2,>=2.23.0 in /miniconda3/lib/python3.7/site-packages (from redshift-connector~=2.0.882->awswrangler->-r requirements.txt (line 3)) (2.25.1)
# 096xlv7tu0-algo-1-vff22 | Collecting lxml>=4.6.2
# 096xlv7tu0-algo-1-vff22 |   Downloading lxml-4.6.3-cp37-cp37m-manylinux2014_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 53.4 MB/s eta 0:00:01
# 096xlv7tu0-algo-1-vff22 | Collecting soupsieve>1.2
# 096xlv7tu0-algo-1-vff22 |   Downloading soupsieve-2.2.1-py3-none-any.whl (33 kB)
# 096xlv7tu0-algo-1-vff22 | Requirement already satisfied: idna<3,>=2.5 in /miniconda3/lib/python3.7/site-packages (from requests<2.25.2,>=2.23.0->redshift-connector~=2.0.882->awswrangler->-r requirements.txt (line 3)) (2.10)
# 096xlv7tu0-algo-1-vff22 | Requirement already satisfied: chardet<5,>=3.0.2 in /miniconda3/lib/python3.7/site-packages (from requests<2.25.2,>=2.23.0->redshift-connector~=2.0.882->awswrangler->-r requirements.txt (line 3)) (4.0.0)
# 096xlv7tu0-algo-1-vff22 | Requirement already satisfied: certifi>=2017.4.17 in /miniconda3/lib/python3.7/site-packages (from requests<2.25.2,>=2.23.0->redshift-connector~=2.0.882->awswrangler->-r requirements.txt (line 3)) (2020.12.5)
# 096xlv7tu0-algo-1-vff22 | Collecting asn1crypto==1.4.0
# 096xlv7tu0-algo-1-vff22 |   Downloading asn1crypto-1.4.0-py2.py3-none-any.whl (104 kB)
#      |████████████████████████████████| 104 kB 103.4 MB/s eta 0:00:01
# 096xlv7tu0-algo-1-vff22 | Collecting importlib-metadata
# 096xlv7tu0-algo-1-vff22 |   Downloading importlib_metadata-4.6.1-py3-none-any.whl (17 kB)
# 096xlv7tu0-algo-1-vff22 | Requirement already satisfied: click in /miniconda3/lib/python3.7/site-packages (from nltk->-r requirements.txt (line 11)) (7.1.2)
# 096xlv7tu0-algo-1-vff22 | Requirement already satisfied: tqdm in /miniconda3/lib/python3.7/site-packages (from nltk->-r requirements.txt (line 11)) (4.59.0)
# 096xlv7tu0-algo-1-vff22 | Collecting regex
# 096xlv7tu0-algo-1-vff22 |   Downloading regex-2021.7.6-cp37-cp37m-manylinux2014_x86_64.whl (721 kB)
#      |████████████████████████████████| 721 kB 56.8 MB/s eta 0:00:01
# 096xlv7tu0-algo-1-vff22 | Collecting attrs
# 096xlv7tu0-algo-1-vff22 |   Downloading attrs-21.2.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 3.8 MB/s  eta 0:00:01
# 096xlv7tu0-algo-1-vff22 | Collecting google-pasta
# 096xlv7tu0-algo-1-vff22 |   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 9.1 MB/s  eta 0:00:01
# 096xlv7tu0-algo-1-vff22 | Requirement already satisfied: protobuf>=3.1 in /miniconda3/lib/python3.7/site-packages (from sagemaker->-r requirements.txt (line 9)) (3.15.6)
# 096xlv7tu0-algo-1-vff22 | Collecting protobuf3-to-dict>=0.1.5
# 096xlv7tu0-algo-1-vff22 |   Downloading protobuf3-to-dict-0.1.5.tar.gz (3.5 kB)
# 096xlv7tu0-algo-1-vff22 | Collecting smdebug_rulesconfig==1.0.1
# 096xlv7tu0-algo-1-vff22 |   Downloading smdebug_rulesconfig-1.0.1-py2.py3-none-any.whl (20 kB)
# 096xlv7tu0-algo-1-vff22 | Collecting packaging>=20.0
# 096xlv7tu0-algo-1-vff22 |   Downloading packaging-21.0-py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 9.0 MB/s  eta 0:00:01
# 096xlv7tu0-algo-1-vff22 | Collecting pathos
# 096xlv7tu0-algo-1-vff22 |   Downloading pathos-0.2.8-py2.py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 16.3 MB/s eta 0:00:01
# 096xlv7tu0-algo-1-vff22 | Collecting zipp>=0.5
# 096xlv7tu0-algo-1-vff22 |   Downloading zipp-3.5.0-py3-none-any.whl (5.7 kB)
# 096xlv7tu0-algo-1-vff22 | Collecting typing-extensions>=3.6.4
# 096xlv7tu0-algo-1-vff22 |   Downloading typing_extensions-3.10.0.0-py3-none-any.whl (26 kB)
# 096xlv7tu0-algo-1-vff22 | Collecting pyparsing>=2.0.2
# 096xlv7tu0-algo-1-vff22 |   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 10.0 MB/s eta 0:00:01
# 096xlv7tu0-algo-1-vff22 | Requirement already satisfied: threadpoolctl>=2.0.0 in /miniconda3/lib/python3.7/site-packages (from scikit-learn->-r requirements.txt (line 6)) (2.1.0)
# 096xlv7tu0-algo-1-vff22 | Requirement already satisfied: scipy>=0.19.1 in /miniconda3/lib/python3.7/site-packages (from scikit-learn->-r requirements.txt (line 6)) (1.5.3)
# 096xlv7tu0-algo-1-vff22 | Collecting pox>=0.3.0
# 096xlv7tu0-algo-1-vff22 |   Downloading pox-0.3.0-py2.py3-none-any.whl (30 kB)
# 096xlv7tu0-algo-1-vff22 | Collecting ppft>=1.6.6.4
# 096xlv7tu0-algo-1-vff22 |   Downloading ppft-1.6.6.4-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 6.9 MB/s  eta 0:00:01
# 096xlv7tu0-algo-1-vff22 | Collecting multiprocess>=0.70.12
# 096xlv7tu0-algo-1-vff22 |   Downloading multiprocess-0.70.12.2-py37-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 109.8 MB/s eta 0:00:01
# 096xlv7tu0-algo-1-vff22 | Collecting dill>=0.3.4
# 096xlv7tu0-algo-1-vff22 |   Downloading dill-0.3.4-py2.py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 10.6 MB/s  eta 0:00:01
# 096xlv7tu0-algo-1-vff22 | Building wheels for collected packages: bs4, progress, sagemaker, protobuf3-to-dict
# 096xlv7tu0-algo-1-vff22 |   Building wheel for bs4 (setup.py) ... done
# 096xlv7tu0-algo-1-vff22 |   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1273 sha256=fb22284125aca184a71be4d22f26ba677607afbce867d1d682aa0266b6f1911f
# 096xlv7tu0-algo-1-vff22 |   Stored in directory: /root/.cache/pip/wheels/0a/9e/ba/20e5bbc1afef3a491f0b3bb74d508f99403aabe76eda2167ca
# 096xlv7tu0-algo-1-vff22 |   Building wheel for progress (setup.py) ... done
# 096xlv7tu0-algo-1-vff22 |   Created wheel for progress: filename=progress-1.6-py3-none-any.whl size=9614 sha256=4d522e2e3a5392e21317d958ce83ab826ee86ca482a7b6542cb052b36a38e7f6
# 096xlv7tu0-algo-1-vff22 |   Stored in directory: /root/.cache/pip/wheels/8e/d7/61/498d8e27dc11e9805b01eb3539e2ee344436fc226daeb5fe87
# 096xlv7tu0-algo-1-vff22 |   Building wheel for sagemaker (setup.py) ... done
# 096xlv7tu0-algo-1-vff22 |   Created wheel for sagemaker: filename=sagemaker-2.50.0-py2.py3-none-any.whl size=594424 sha256=3c536adc1931a13547c3f859f597188b7d14ffcd6e1c08e314732c5f9ab5bfab
# 096xlv7tu0-algo-1-vff22 |   Stored in directory: /root/.cache/pip/wheels/1d/52/89/ef23101a7e4cffd95e26bb680a154e66660f57475bed6f9936
# 096xlv7tu0-algo-1-vff22 |   Building wheel for protobuf3-to-dict (setup.py) ... done
# 096xlv7tu0-algo-1-vff22 |   Created wheel for protobuf3-to-dict: filename=protobuf3_to_dict-0.1.5-py3-none-any.whl size=4030 sha256=41e10661db6e818bbfe94a37872c628781df28b3bb91eeefa0a3faf39db6c691
# 096xlv7tu0-algo-1-vff22 |   Stored in directory: /root/.cache/pip/wheels/ce/a0/8b/995ce2fbaf0e9fe7eb91da84e99e84d1b35cfaa555f2b8f1c7
# 096xlv7tu0-algo-1-vff22 | Successfully built bs4 progress sagemaker protobuf3-to-dict
# 096xlv7tu0-algo-1-vff22 | Installing collected packages: botocore, soupsieve, s3transfer, dill, asn1crypto, zipp, typing-extensions, scramp, pyparsing, ppft, pox, multiprocess, lxml, et-xmlfile, boto3, beautifulsoup4, smdebug-rulesconfig, regex, redshift-connector, pymysql, pyarrow, protobuf3-to-dict, pg8000, pathos, packaging, openpyxl, importlib-metadata, google-pasta, attrs, sagemaker, progress, nltk, markdown, bs4, awswrangler
# 096xlv7tu0-algo-1-vff22 |   Attempting uninstall: botocore
# 096xlv7tu0-algo-1-vff22 |     Found existing installation: botocore 1.19.4
# 096xlv7tu0-algo-1-vff22 |     Uninstalling botocore-1.19.4:
# 096xlv7tu0-algo-1-vff22 |       Successfully uninstalled botocore-1.19.4
# 096xlv7tu0-algo-1-vff22 |   Attempting uninstall: s3transfer
# 096xlv7tu0-algo-1-vff22 |     Found existing installation: s3transfer 0.3.6
# 096xlv7tu0-algo-1-vff22 |     Uninstalling s3transfer-0.3.6:
# 096xlv7tu0-algo-1-vff22 |       Successfully uninstalled s3transfer-0.3.6
# 096xlv7tu0-algo-1-vff22 |   Attempting uninstall: boto3
# 096xlv7tu0-algo-1-vff22 |     Found existing installation: boto3 1.16.4
# 096xlv7tu0-algo-1-vff22 |     Uninstalling boto3-1.16.4:
# 096xlv7tu0-algo-1-vff22 |       Successfully uninstalled boto3-1.16.4
# 096xlv7tu0-algo-1-vff22 |   Attempting uninstall: pyarrow
# 096xlv7tu0-algo-1-vff22 |     Found existing installation: pyarrow 0.16.0
# 096xlv7tu0-algo-1-vff22 |     Uninstalling pyarrow-0.16.0:
# 096xlv7tu0-algo-1-vff22 |       Successfully uninstalled pyarrow-0.16.0
# 096xlv7tu0-algo-1-vff22 | ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# 096xlv7tu0-algo-1-vff22 | sagemaker-sklearn-container 2.0 requires boto3==1.16.4, but you have boto3 1.18.11 which is incompatible.
# 096xlv7tu0-algo-1-vff22 | sagemaker-sklearn-container 2.0 requires botocore==1.19.4, but you have botocore 1.21.11 which is incompatible.
# 096xlv7tu0-algo-1-vff22 | Successfully installed asn1crypto-1.4.0 attrs-21.2.0 awswrangler-2.10.0 beautifulsoup4-4.9.3 boto3-1.18.11 botocore-1.21.11 bs4-0.0.1 dill-0.3.4 et-xmlfile-1.1.0 google-pasta-0.2.0 importlib-metadata-4.6.1 lxml-4.6.3 markdown-3.3.4 multiprocess-0.70.12.2 nltk-3.6.2 openpyxl-3.0.7 packaging-21.0 pathos-0.2.8 pg8000-1.20.0 pox-0.3.0 ppft-1.6.6.4 progress-1.6 protobuf3-to-dict-0.1.5 pyarrow-4.0.1 pymysql-1.0.2 pyparsing-2.4.7 redshift-connector-2.0.883 regex-2021.7.6 s3transfer-0.5.0 sagemaker-2.50.0 scramp-1.4.0 smdebug-rulesconfig-1.0.1 soupsieve-2.2.1 typing-extensions-3.10.0.0 zipp-3.5.0
# 096xlv7tu0-algo-1-vff22 | 2021-07-30 23:01:14,442 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 096xlv7tu0-algo-1-vff22 | 2021-07-30 23:01:14,454 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 096xlv7tu0-algo-1-vff22 | 2021-07-30 23:01:14,465 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 096xlv7tu0-algo-1-vff22 | 2021-07-30 23:01:14,474 sagemaker-training-toolkit INFO     Invoking user script
# 096xlv7tu0-algo-1-vff22 |
# 096xlv7tu0-algo-1-vff22 | Training Env:
# 096xlv7tu0-algo-1-vff22 |
# 096xlv7tu0-algo-1-vff22 | {
# 096xlv7tu0-algo-1-vff22 |     "additional_framework_parameters": {},
# 096xlv7tu0-algo-1-vff22 |     "channel_input_dirs": {
# 096xlv7tu0-algo-1-vff22 |         "train": "/opt/ml/input/data/train"
# 096xlv7tu0-algo-1-vff22 |     },
# 096xlv7tu0-algo-1-vff22 |     "current_host": "algo-1-vff22",
# 096xlv7tu0-algo-1-vff22 |     "framework_module": "sagemaker_sklearn_container.training:main",
# 096xlv7tu0-algo-1-vff22 |     "hosts": [
# 096xlv7tu0-algo-1-vff22 |         "algo-1-vff22"
# 096xlv7tu0-algo-1-vff22 |     ],
# 096xlv7tu0-algo-1-vff22 |     "hyperparameters": {
# 096xlv7tu0-algo-1-vff22 |         "n-best": 10
# 096xlv7tu0-algo-1-vff22 |     },
# 096xlv7tu0-algo-1-vff22 |     "input_config_dir": "/opt/ml/input/config",
# 096xlv7tu0-algo-1-vff22 |     "input_data_config": {
# 096xlv7tu0-algo-1-vff22 |         "train": {
# 096xlv7tu0-algo-1-vff22 |             "TrainingInputMode": "File"
# 096xlv7tu0-algo-1-vff22 |         }
# 096xlv7tu0-algo-1-vff22 |     },
# 096xlv7tu0-algo-1-vff22 |     "input_dir": "/opt/ml/input",
# 096xlv7tu0-algo-1-vff22 |     "is_master": true,
# 096xlv7tu0-algo-1-vff22 |     "job_name": "sagemaker-scikit-learn-2021-07-30-23-00-55-659",
# 096xlv7tu0-algo-1-vff22 |     "log_level": 20,
# 096xlv7tu0-algo-1-vff22 |     "master_hostname": "algo-1-vff22",
# 096xlv7tu0-algo-1-vff22 |     "model_dir": "/opt/ml/model",
# 096xlv7tu0-algo-1-vff22 |     "module_dir": "s3://sagemaker-us-west-2-092109498566/sagemaker-scikit-learn-2021-07-30-23-00-55-659/source/sourcedir.tar.gz",
# 096xlv7tu0-algo-1-vff22 |     "module_name": "train",
# 096xlv7tu0-algo-1-vff22 |     "network_interface_name": "eth0",
# 096xlv7tu0-algo-1-vff22 |     "num_cpus": 16,
# 096xlv7tu0-algo-1-vff22 |     "num_gpus": 0,
# 096xlv7tu0-algo-1-vff22 |     "output_data_dir": "/opt/ml/output/data",
# 096xlv7tu0-algo-1-vff22 |     "output_dir": "/opt/ml/output",
# 096xlv7tu0-algo-1-vff22 |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# 096xlv7tu0-algo-1-vff22 |     "resource_config": {
# 096xlv7tu0-algo-1-vff22 |         "current_host": "algo-1-vff22",
# 096xlv7tu0-algo-1-vff22 |         "hosts": [
# 096xlv7tu0-algo-1-vff22 |             "algo-1-vff22"
# 096xlv7tu0-algo-1-vff22 |         ]
# 096xlv7tu0-algo-1-vff22 |     },
# 096xlv7tu0-algo-1-vff22 |     "user_entry_point": "train.py"
# 096xlv7tu0-algo-1-vff22 | }
# 096xlv7tu0-algo-1-vff22 |
# 096xlv7tu0-algo-1-vff22 | Environment variables:
# 096xlv7tu0-algo-1-vff22 |
# 096xlv7tu0-algo-1-vff22 | SM_HOSTS=["algo-1-vff22"]
# 096xlv7tu0-algo-1-vff22 | SM_NETWORK_INTERFACE_NAME=eth0
# 096xlv7tu0-algo-1-vff22 | SM_HPS={"n-best":10}
# 096xlv7tu0-algo-1-vff22 | SM_USER_ENTRY_POINT=train.py
# 096xlv7tu0-algo-1-vff22 | SM_FRAMEWORK_PARAMS={}
# 096xlv7tu0-algo-1-vff22 | SM_RESOURCE_CONFIG={"current_host":"algo-1-vff22","hosts":["algo-1-vff22"]}
# 096xlv7tu0-algo-1-vff22 | SM_INPUT_DATA_CONFIG={"train":{"TrainingInputMode":"File"}}
# 096xlv7tu0-algo-1-vff22 | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# 096xlv7tu0-algo-1-vff22 | SM_CHANNELS=["train"]
# 096xlv7tu0-algo-1-vff22 | SM_CURRENT_HOST=algo-1-vff22
# 096xlv7tu0-algo-1-vff22 | SM_MODULE_NAME=train
# 096xlv7tu0-algo-1-vff22 | SM_LOG_LEVEL=20
# 096xlv7tu0-algo-1-vff22 | SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# 096xlv7tu0-algo-1-vff22 | SM_INPUT_DIR=/opt/ml/input
# 096xlv7tu0-algo-1-vff22 | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# 096xlv7tu0-algo-1-vff22 | SM_OUTPUT_DIR=/opt/ml/output
# 096xlv7tu0-algo-1-vff22 | SM_NUM_CPUS=16
# 096xlv7tu0-algo-1-vff22 | SM_NUM_GPUS=0
# 096xlv7tu0-algo-1-vff22 | SM_MODEL_DIR=/opt/ml/model
# 096xlv7tu0-algo-1-vff22 | SM_MODULE_DIR=s3://sagemaker-us-west-2-092109498566/sagemaker-scikit-learn-2021-07-30-23-00-55-659/source/sourcedir.tar.gz
# 096xlv7tu0-algo-1-vff22 | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1-vff22","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1-vff22"],"hyperparameters":{"n-best":10},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-scikit-learn-2021-07-30-23-00-55-659","log_level":20,"master_hostname":"algo-1-vff22","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-092109498566/sagemaker-scikit-learn-2021-07-30-23-00-55-659/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":16,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-vff22","hosts":["algo-1-vff22"]},"user_entry_point":"train.py"}
# 096xlv7tu0-algo-1-vff22 | SM_USER_ARGS=["--n-best","10"]
# 096xlv7tu0-algo-1-vff22 | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# 096xlv7tu0-algo-1-vff22 | SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# 096xlv7tu0-algo-1-vff22 | SM_HP_N-BEST=10
# 096xlv7tu0-algo-1-vff22 | PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
# 096xlv7tu0-algo-1-vff22 |
# 096xlv7tu0-algo-1-vff22 | Invoking script with the following command:
# 096xlv7tu0-algo-1-vff22 |
# 096xlv7tu0-algo-1-vff22 | /miniconda3/bin/python train.py --n-best 10
# 096xlv7tu0-algo-1-vff22 |
# 096xlv7tu0-algo-1-vff22 |
# 096xlv7tu0-algo-1-vff22 | /opt/ml/input/data/train
# 096xlv7tu0-algo-1-vff22 | ['run-DataSink0-5-part-block-0-r-00004-snappy.parquet', 'run-DataSink0-5-part-block-0-r-00005-snappy.parquet', 'run-DataSink0-5-part-block-0-r-00016-snappy.parquet', 'run-DataSink0-5-part-block-0-r-00008-snappy.parquet', 'run-DataSink0-5-part-block-0-r-00001-snappy.parquet', 'run-DataSink0-5-part-block-0-r-00002-snappy.parquet', 'run-DataSink0-5-part-block-0-r-00017-snappy.parquet', 'run-DataSink0-5-part-block-0-r-00015-snappy.parquet', 'run-DataSink0-5-part-block-0-r-00010-snappy.parquet', 'run-DataSink0-5-part-block-0-r-00011-snappy.parquet', 'run-DataSink0-5-part-block-0-r-00013-snappy.parquet', 'run-DataSink0-5-part-block-0-r-00000-snappy.parquet', 'run-DataSink0-5-part-block-0-r-00003-snappy.parquet', 'run-DataSink0-5-part-block-0-r-00014-snappy.parquet', 'run-DataSink0-5-part-block-0-r-00012-snappy.parquet', 'run-DataSink0-5-part-block-0-r-00009-snappy.parquet', 'run-DataSink0-5-part-block-0-r-00007-snappy.parquet', 'run-DataSink0-5-part-block-0-r-00006-snappy.parquet']
# 096xlv7tu0-algo-1-vff22 | ['/opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00004-snappy.parquet', '/opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00005-snappy.parquet', '/opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00016-snappy.parquet', '/opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00008-snappy.parquet', '/opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00001-snappy.parquet', '/opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00002-snappy.parquet', '/opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00017-snappy.parquet', '/opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00015-snappy.parquet', '/opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00010-snappy.parquet', '/opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00011-snappy.parquet', '/opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00013-snappy.parquet', '/opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00000-snappy.parquet', '/opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00003-snappy.parquet', '/opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00014-snappy.parquet', '/opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00012-snappy.parquet', '/opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00009-snappy.parquet', '/opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00007-snappy.parquet', '/opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00006-snappy.parquet']
# 096xlv7tu0-algo-1-vff22 | .parquet
# 096xlv7tu0-algo-1-vff22 | .parquet
# 096xlv7tu0-algo-1-vff22 | .parquet
# 096xlv7tu0-algo-1-vff22 | .parquet
# 096xlv7tu0-algo-1-vff22 | .parquet
# 096xlv7tu0-algo-1-vff22 | .parquet
# 096xlv7tu0-algo-1-vff22 | .parquet
# 096xlv7tu0-algo-1-vff22 | .parquet
# 096xlv7tu0-algo-1-vff22 | .parquet
# 096xlv7tu0-algo-1-vff22 | .parquet
# 096xlv7tu0-algo-1-vff22 | .parquet
# 096xlv7tu0-algo-1-vff22 | .parquet
# 096xlv7tu0-algo-1-vff22 | .parquet
# 096xlv7tu0-algo-1-vff22 | .parquet
# 096xlv7tu0-algo-1-vff22 | .parquet
# 096xlv7tu0-algo-1-vff22 | .parquet
# 096xlv7tu0-algo-1-vff22 | .parquet
# 096xlv7tu0-algo-1-vff22 | .parquet
# 096xlv7tu0-algo-1-vff22 | Training model...
# 096xlv7tu0-algo-1-vff22 | /miniconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:386: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ha', 'le', 'u', 'wa'] not in stop_words.
# 096xlv7tu0-algo-1-vff22 |   'stop_words.' % sorted(inconsistent))
# 096xlv7tu0-algo-1-vff22 | 65468
# 096xlv7tu0-algo-1-vff22 | Took 32.02721285820007 seconds
# 096xlv7tu0-algo-1-vff22 | 2021-07-30 23:01:56,497 sagemaker-containers INFO     Reporting training SUCCESS
# 096xlv7tu0-algo-1-vff22 exited with code 0
# Aborting on container exit...
# =======
# 2021-07-31 00:05:15 Starting - Starting the training job...
# 2021-07-31 00:05:38 Starting - Launching requested ML instancesProfilerReport-1627689913: InProgress
# ......
# 2021-07-31 00:06:39 Starting - Preparing the instances for training......
# 2021-07-31 00:07:42 Downloading - Downloading input data...
# 2021-07-31 00:08:10 Training - Downloading the training image..
# 2021-07-31 00:08:39 Training - Training image download completed. Training in progress.2021-07-31 00:08:27,381 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2021-07-31 00:08:27,383 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-07-31 00:08:27,392 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2021-07-31 00:08:28,100 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /miniconda3/bin/python -m pip install -r requirements.txt
# Requirement already satisfied: pip in /miniconda3/lib/python3.7/site-packages (from -r requirements.txt (line 1)) (21.0.1)
# Collecting progress
#   Downloading progress-1.6.tar.gz (7.8 kB)
# Collecting awswrangler
#   Downloading awswrangler-2.10.0-py3-none-any.whl (184 kB)
# Requirement already satisfied: boto3 in /miniconda3/lib/python3.7/site-packages (from -r requirements.txt (line 4)) (1.16.4)
# Requirement already satisfied: pandas in /miniconda3/lib/python3.7/site-packages (from -r requirements.txt (line 5)) (1.1.3)
# Requirement already satisfied: scikit-learn in /miniconda3/lib/python3.7/site-packages (from -r requirements.txt (line 6)) (0.23.2)
# Collecting markdown
#   Downloading Markdown-3.3.4-py3-none-any.whl (97 kB)
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
# Collecting sagemaker
#   Downloading sagemaker-2.50.0.tar.gz (423 kB)
# Requirement already satisfied: joblib in /miniconda3/lib/python3.7/site-packages (from -r requirements.txt (line 10)) (1.0.1)
# Collecting nltk
#   Downloading nltk-3.6.2-py3-none-any.whl (1.5 MB)
# Collecting pg8000<1.21.0,>=1.16.0
#   Downloading pg8000-1.20.0-py3-none-any.whl (34 kB)
# Collecting botocore<2.1.0,>=1.19.8
#   Downloading botocore-1.21.11-py3-none-any.whl (7.8 MB)
# Collecting pymysql<1.1.0,>=0.9.0
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
# Collecting redshift-connector~=2.0.882
#   Downloading redshift_connector-2.0.883-py3-none-any.whl (93 kB)
# Collecting pyarrow<4.1.0,>=2.0.0
#   Downloading pyarrow-4.0.1-cp37-cp37m-manylinux2014_x86_64.whl (21.8 MB)
# Requirement already satisfied: numpy<2.1.0,>=1.18.0 in /miniconda3/lib/python3.7/site-packages (from awswrangler->-r requirements.txt (line 3)) (1.19.2)
# Collecting boto3
#   Downloading boto3-1.18.11-py3-none-any.whl (131 kB)
# Collecting openpyxl~=3.0.0
#   Downloading openpyxl-3.0.7-py2.py3-none-any.whl (243 kB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.0-py3-none-any.whl (79 kB)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /miniconda3/lib/python3.7/site-packages (from boto3->-r requirements.txt (line 4)) (0.10.0)
# Requirement already satisfied: pytz>=2017.2 in /miniconda3/lib/python3.7/site-packages (from pandas->-r requirements.txt (line 5)) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /miniconda3/lib/python3.7/site-packages (from pandas->-r requirements.txt (line 5)) (2.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /miniconda3/lib/python3.7/site-packages (from botocore<2.1.0,>=1.19.8->awswrangler->-r requirements.txt (line 3)) (1.25.11)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Collecting scramp>=1.4.0
#   Downloading scramp-1.4.0-py3-none-any.whl (8.4 kB)
# Requirement already satisfied: six>=1.5 in /miniconda3/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas->-r requirements.txt (line 5)) (1.15.0)
# Collecting beautifulsoup4<5.0.0,>=4.7.0
#   Downloading beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
# Requirement already satisfied: requests<2.25.2,>=2.23.0 in /miniconda3/lib/python3.7/site-packages (from redshift-connector~=2.0.882->awswrangler->-r requirements.txt (line 3)) (2.25.1)
# Collecting lxml>=4.6.2
#   Downloading lxml-4.6.3-cp37-cp37m-manylinux2014_x86_64.whl (6.3 MB)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.2.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: chardet<5,>=3.0.2 in /miniconda3/lib/python3.7/site-packages (from requests<2.25.2,>=2.23.0->redshift-connector~=2.0.882->awswrangler->-r requirements.txt (line 3)) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /miniconda3/lib/python3.7/site-packages (from requests<2.25.2,>=2.23.0->redshift-connector~=2.0.882->awswrangler->-r requirements.txt (line 3)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /miniconda3/lib/python3.7/site-packages (from requests<2.25.2,>=2.23.0->redshift-connector~=2.0.882->awswrangler->-r requirements.txt (line 3)) (2020.12.5)
# Collecting asn1crypto==1.4.0
#   Downloading asn1crypto-1.4.0-py2.py3-none-any.whl (104 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-4.6.1-py3-none-any.whl (17 kB)
# Collecting regex
#   Downloading regex-2021.7.6-cp37-cp37m-manylinux2014_x86_64.whl (721 kB)
# Requirement already satisfied: click in /miniconda3/lib/python3.7/site-packages (from nltk->-r requirements.txt (line 11)) (7.1.2)
# Requirement already satisfied: tqdm in /miniconda3/lib/python3.7/site-packages (from nltk->-r requirements.txt (line 11)) (4.59.0)
# Collecting attrs
#   Downloading attrs-21.2.0-py2.py3-none-any.whl (53 kB)
# Collecting google-pasta
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: protobuf>=3.1 in /miniconda3/lib/python3.7/site-packages (from sagemaker->-r requirements.txt (line 9)) (3.15.6)
# Collecting protobuf3-to-dict>=0.1.5
#   Downloading protobuf3-to-dict-0.1.5.tar.gz (3.5 kB)
# Collecting smdebug_rulesconfig==1.0.1
#   Downloading smdebug_rulesconfig-1.0.1-py2.py3-none-any.whl (20 kB)
# Collecting packaging>=20.0
#   Downloading packaging-21.0-py3-none-any.whl (40 kB)
# Collecting pathos
#   Downloading pathos-0.2.8-py2.py3-none-any.whl (81 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.5.0-py3-none-any.whl (5.7 kB)
# Collecting typing-extensions>=3.6.4
#   Downloading typing_extensions-3.10.0.0-py3-none-any.whl (26 kB)
# Collecting pyparsing>=2.0.2
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /miniconda3/lib/python3.7/site-packages (from scikit-learn->-r requirements.txt (line 6)) (2.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /miniconda3/lib/python3.7/site-packages (from scikit-learn->-r requirements.txt (line 6)) (1.5.3)
# Collecting dill>=0.3.4
#   Downloading dill-0.3.4-py2.py3-none-any.whl (86 kB)
# Collecting pox>=0.3.0
#   Downloading pox-0.3.0-py2.py3-none-any.whl (30 kB)
# Collecting multiprocess>=0.70.12
#   Downloading multiprocess-0.70.12.2-py37-none-any.whl (112 kB)
# Collecting ppft>=1.6.6.4
#   Downloading ppft-1.6.6.4-py3-none-any.whl (65 kB)
# Building wheels for collected packages: bs4, progress, sagemaker, protobuf3-to-dict
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1273 sha256=699f3ee7a65ba2998a3495baafd09b1b8aa7d8dafdd1e98a7a6efa59321ec60b
#   Stored in directory: /root/.cache/pip/wheels/0a/9e/ba/20e5bbc1afef3a491f0b3bb74d508f99403aabe76eda2167ca
#   Building wheel for progress (setup.py): started
#   Building wheel for progress (setup.py): finished with status 'done'
#   Created wheel for progress: filename=progress-1.6-py3-none-any.whl size=9614 sha256=481bd7ad1158077b82f39fd10fe4fc7a4a91647df25a19b9122a2befd57ee8dd
#   Stored in directory: /root/.cache/pip/wheels/8e/d7/61/498d8e27dc11e9805b01eb3539e2ee344436fc226daeb5fe87
#   Building wheel for sagemaker (setup.py): started
#   Building wheel for sagemaker (setup.py): finished with status 'done'
#   Created wheel for sagemaker: filename=sagemaker-2.50.0-py2.py3-none-any.whl size=594424 sha256=e6e6e2e685cbd9b6760b64337c4d38a815eb8ed3924b1d5b5f8e21c4abaec131
#   Stored in directory: /root/.cache/pip/wheels/1d/52/89/ef23101a7e4cffd95e26bb680a154e66660f57475bed6f9936
#   Building wheel for protobuf3-to-dict (setup.py): started
#   Building wheel for protobuf3-to-dict (setup.py): finished with status 'done'
#   Created wheel for protobuf3-to-dict: filename=protobuf3_to_dict-0.1.5-py3-none-any.whl size=4030 sha256=045eebd7ad563bec309cf3b5478e17d732a6d6512e3edf6e1e512a3857655085
#   Stored in directory: /root/.cache/pip/wheels/ce/a0/8b/995ce2fbaf0e9fe7eb91da84e99e84d1b35cfaa555f2b8f1c7
# Successfully built bs4 progress sagemaker protobuf3-to-dict
# Installing collected packages: botocore, soupsieve, s3transfer, dill, asn1crypto, zipp, typing-extensions, scramp, pyparsing, ppft, pox, multiprocess, lxml, et-xmlfile, boto3, beautifulsoup4, smdebug-rulesconfig, regex, redshift-connector, pymysql, pyarrow, protobuf3-to-dict, pg8000, pathos, packaging, openpyxl, importlib-metadata, google-pasta, attrs, sagemaker, progress, nltk, markdown, bs4, awswrangler
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.19.4
#     Uninstalling botocore-1.19.4:
#       Successfully uninstalled botocore-1.19.4
#   Attempting uninstall: s3transfer
#     Found existing installation: s3transfer 0.3.6
#     Uninstalling s3transfer-0.3.6:
#       Successfully uninstalled s3transfer-0.3.6
#   Attempting uninstall: boto3
#     Found existing installation: boto3 1.16.4
#     Uninstalling boto3-1.16.4:
#       Successfully uninstalled boto3-1.16.4
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 0.16.0
#     Uninstalling pyarrow-0.16.0:
#       Successfully uninstalled pyarrow-0.16.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sagemaker-sklearn-container 2.0 requires boto3==1.16.4, but you have boto3 1.18.11 which is incompatible.
# sagemaker-sklearn-container 2.0 requires botocore==1.19.4, but you have botocore 1.21.11 which is incompatible.
# Successfully installed asn1crypto-1.4.0 attrs-21.2.0 awswrangler-2.10.0 beautifulsoup4-4.9.3 boto3-1.18.11 botocore-1.21.11 bs4-0.0.1 dill-0.3.4 et-xmlfile-1.1.0 google-pasta-0.2.0 importlib-metadata-4.6.1 lxml-4.6.3 markdown-3.3.4 multiprocess-0.70.12.2 nltk-3.6.2 openpyxl-3.0.7 packaging-21.0 pathos-0.2.8 pg8000-1.20.0 pox-0.3.0 ppft-1.6.6.4 progress-1.6 protobuf3-to-dict-0.1.5 pyarrow-4.0.1 pymysql-1.0.2 pyparsing-2.4.7 redshift-connector-2.0.883 regex-2021.7.6 s3transfer-0.5.0 sagemaker-2.50.0 scramp-1.4.0 smdebug-rulesconfig-1.0.1 soupsieve-2.2.1 typing-extensions-3.10.0.0 zipp-3.5.0
# 2021-07-31 00:08:43,636 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-07-31 00:08:43,648 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-07-31 00:08:43,661 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-07-31 00:08:43,670 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "n-best": 10
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "sagemaker-scikit-learn-2021-07-31-00-05-12-960",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-092109498566/sagemaker-scikit-learn-2021-07-31-00-05-12-960/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 16,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"n-best":10}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=16
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-2-092109498566/sagemaker-scikit-learn-2021-07-31-00-05-12-960/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"n-best":10},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-scikit-learn-2021-07-31-00-05-12-960","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-092109498566/sagemaker-scikit-learn-2021-07-31-00-05-12-960/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":16,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--n-best","10"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_N-BEST=10
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python train.py --n-best 10
#
#
# /opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00015-snappy.parquet
# /opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00016-snappy.parquet
# /opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00011-snappy.parquet
# /opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00004-snappy.parquet
# /opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00002-snappy.parquet
# /opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00003-snappy.parquet
# /opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00017-snappy.parquet
# /opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00001-snappy.parquet
# /opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00014-snappy.parquet
# /opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00005-snappy.parquet
# /opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00009-snappy.parquet
# Traceback (most recent call last):
#   File "train.py", line 59, in <module>
# /opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00008-snappy.parquet
# /opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00010-snappy.parquet
# /opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00007-snappy.parquet
# /opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00000-snappy.parquet
# /opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00012-snappy.parquet
# /opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00006-snappy.parquet
# /opt/ml/input/data/train/run-DataSink0-5-part-block-0-r-00013-snappy.parquet
#     train_df = load_files(args.train)
#   File "train.py", line 48, in load_files
#     df = combine_dfs(dfs)
#   File "train.py", line 31, in combine_dfs
#     df = pd.concat(dfs, ignore_index=True)
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py", line 284, in concat
#     sort=sort,
#   File "/miniconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py", line 331, in __init__
#     raise ValueError("No objects to concatenate")
# ValueError: No objects to concatenate
# 2021-07-31 00:08:46,686 sagemaker-containers ERROR    Reporting training FAILURE
# 2021-07-31 00:08:46,686 sagemaker-containers ERROR    framework error:
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_containers/_trainer.py", line 84, in train
#     entrypoint()
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_sklearn_container/training.py", line 39, in main
#     train(environment.Environment())
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_sklearn_container/training.py", line 35, in train
#     runner_type=runner.ProcessRunnerType)
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_training/entry_point.py", line 100, in run
#     wait, capture_error
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_training/process.py", line 161, in run
#     cwd=environment.code_dir,
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_training/process.py", line 81, in check_error
#     raise error_class(return_code=return_code, cmd=" ".join(cmd), output=stderr)
# sagemaker_training.errors.ExecuteUserScriptError: ExecuteUserScriptError:
# Command "/miniconda3/bin/python train.py --n-best 10"
#
# ExecuteUserScriptError:
# Command "/miniconda3/bin/python train.py --n-best 10"
#
# 2021-07-31 00:09:01 Uploading - Uploading generated training model
# 2021-07-31 00:09:01 Failed - Training job failed
# ProfilerReport-1627689913: Stopping
# ---------------------------------------------------------------------------
# UnexpectedStatusException                 Traceback (most recent call last)
# <ipython-input-4-97595879d297> in <module>
#       9     dependencies=['.']
#      10 )
# ---> 11 sklearn_estimator.fit({'train': train_data})
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     681         self.jobs.append(self.latest_training_job)
#     682         if wait:
# --> 683             self.latest_training_job.wait(logs=logs)
#     684
#     685     def _compilation_job_name(self):
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/estimator.py in wait(self, logs)
#    1626         # If logs are requested, call logs_for_jobs.
#    1627         if logs != "None":
# -> 1628             self.sagemaker_session.logs_for_job(self.job_name, wait=True, log_type=logs)
#    1629         else:
#    1630             self.sagemaker_session.wait_for_job(self.job_name)
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/session.py in logs_for_job(self, job_name, wait, poll, log_type)
#    3658
#    3659         if wait:
# -> 3660             self._check_job_status(job_name, description, "TrainingJobStatus")
#    3661             if dot:
#    3662                 print()
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/session.py in _check_job_status(self, job, desc, status_key_name)
#    3218                 ),
#    3219                 allowed_statuses=["Completed", "Stopped"],
# -> 3220                 actual_status=status,
#    3221             )
#    3222
#
# UnexpectedStatusException: Error for Training job sagemaker-scikit-learn-2021-07-31-00-05-12-960: Failed. Reason: AlgorithmError: framework error:
# Traceback (most recent call last):
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_containers/_trainer.py", line 84, in train
#     entrypoint()
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_sklearn_container/training.py", line 39, in main
#     train(environment.Environment())
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_sklearn_container/training.py", line 35, in train
#     runner_type=runner.ProcessRunnerType)
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_training/entry_point.py", line 100, in run
#     wait, capture_error
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_training/process.py", line 161, in run
#     cwd=environment.code_dir,
#   File "/miniconda3/lib/python3.7/site-packages/sagemaker_training/process.py", line 81, in check_error
#     raise error_class(return_code=return_code, cmd=" ".join(cmd), output=stderr)
# sagemaker_training.errors.ExecuteUserScriptError: ExecuteUserScriptError:
# Command "/miniconda3/bin/python
# >>>>>>> remote
# Using the short-lived AWS credentials found in session. They might expire while running.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-41-8188f064c34d> in <module>
#      10     dependencies=['.']
#      11 )
# ---> 12 sklearn_estimator.fit({'train': train_data})
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     678         self._prepare_for_training(job_name=job_name)
#     679
# --> 680         self.latest_training_job = _TrainingJob.start_new(self, inputs, experiment_config)
#     681         self.jobs.append(self.latest_training_job)
#     682         if wait:
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/estimator.py in start_new(cls, estimator, inputs, experiment_config)
#    1450         """
#    1451         train_args = cls._get_train_args(estimator, inputs, experiment_config)
# -> 1452         estimator.sagemaker_session.train(**train_args)
#    1453
#    1454         return cls(estimator.sagemaker_session, estimator._current_job_name)
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/session.py in train(self, input_mode, input_config, role, job_name, output_config, resource_config, vpc_config, hyperparameters, stop_condition, tags, metric_definitions, enable_network_isolation, image_uri, algorithm_arn, encrypt_inter_container_traffic, use_spot_instances, checkpoint_s3_uri, checkpoint_local_path, experiment_config, debugger_rule_configs, debugger_hook_config, tensorboard_output_config, enable_sagemaker_metrics, profiler_rule_configs, profiler_config, environment, retry_strategy)
#     572         LOGGER.info("Creating training-job with name: %s", job_name)
#     573         LOGGER.debug("train request: %s", json.dumps(train_request, indent=4))
# --> 574         self.sagemaker_client.create_training_job(**train_request)
#     575
#     576     def _get_train_request(  # noqa: C901
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/local/local_session.py in create_training_job(self, TrainingJobName, AlgorithmSpecification, OutputDataConfig, ResourceConfig, InputDataConfig, **kwargs)
#     184         hyperparameters = kwargs["HyperParameters"] if "HyperParameters" in kwargs else {}
#     185         logger.info("Starting training job")
# --> 186         training_job.start(InputDataConfig, OutputDataConfig, hyperparameters, TrainingJobName)
#     187
#     188         LocalSagemakerClient._training_jobs[TrainingJobName] = training_job
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/local/entities.py in start(self, input_data_config, output_data_config, hyperparameters, job_name)
#     219
#     220         self.model_artifacts = self.container.train(
# --> 221             input_data_config, output_data_config, hyperparameters, job_name
#     222         )
#     223         self.end_time = datetime.datetime.now()
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/local/image.py in train(self, input_data_config, output_data_config, hyperparameters, job_name)
#     228         compose_command = self._compose()
#     229
# --> 230         if _ecr_login_if_needed(self.sagemaker_session.boto_session, self.image):
#     231             _pull_image(self.image)
#     232
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/local/image.py in _ecr_login_if_needed(boto_session, image)
#    1057
#    1058     # do we have the image?
# -> 1059     if _check_output("docker images -q %s" % image).strip():
#    1060         return False
#    1061
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/local/image.py in _check_output(cmd, *popenargs, **kwargs)
#     910     success = True
#     911     try:
# --> 912         output = subprocess.check_output(cmd, *popenargs, **kwargs)
#     913     except subprocess.CalledProcessError as e:
#     914         output = e.output
#
# /opt/conda/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     409
#     410     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 411                **kwargs).stdout
#     412
#     413
#
# /opt/conda/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486         kwargs['stderr'] = PIPE
#     487
# --> 488     with Popen(*popenargs, **kwargs) as process:
#     489         try:
#     490             stdout, stderr = process.communicate(input, timeout=timeout)
#
# /opt/conda/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     798                                 c2pread, c2pwrite,
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#     802             # Cleanup if the child failed starting.
#
# /opt/conda/lib/python3.7/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1549                         if errno_num == errno.ENOENT:
#    1550                             err_msg += ': ' + repr(err_filename)
# -> 1551                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1552                 raise child_exception_type(err_msg)
#    1553
#
# FileNotFoundError: [Errno 2] No such file or directory: 'docker': 'docker'

# %%
# Deploy SM predictor
# predictor = sklearn_estimator.deploy(instance_type='ml.m5.4xlarge',
#                                      initial_instance_count=1,
# #                                      update_endpoint=True,
#                                     endpoint_name='issue-similarity-endpoint')
predictor = Predictor('issue-similarity-endpoint')
model = sklearn_estimator.create_model()
session = model.sagemaker_session
role = sagemaker.get_execution_role()
model_name = model.name
container_def = model.prepare_container_def(instance_type='ml.m5.4xlarge')
session.create_model(model_name, role, container_def)


endpoint_config_name = session.create_endpoint_config(name=model_name,
                                                      model_name=model_name,
                                                      initial_instance_count=1,
                                                      instance_type='ml.m5.4xlarge')

# Update desired endpoint with new Endpoint Config
client = boto3.client('sagemaker')
client.update_endpoint(EndpointName='issue-similarity-endpoint',
                       EndpointConfigName=endpoint_config_name)

# predictor.update_endpoint(
#     instance_type='ml.m5.4xlarge',
#     model_name = sklearn_estimator.create_model().name,
#     initial_instance_count=1
# )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8e8ac4f86caf> in <module>
#       4 # #                                      update_endpoint=True,
#       5 #                                     endpoint_name='issue-similarity-endpoint')
# ----> 6 predictor = Predictor('issue-similarity-endpoint')
#       7 model = sklearn_estimator.create_model()
#       8 session = model.sagemaker_session
#
# NameError: name 'Predictor' is not defined

# %%
data = ['DataStore model subscription fails']
data = json.dumps({'data': data})
response = predictor.predict(data)
print(response)
# Out:
# b'[[[["https://github.com/aws-amplify/amplify-cli/issues/3114", "DataStore generates subscriptions for all @model types"], ["https://github.com/aws-amplify/amplify-js/issues/5648", "DataStore keeps searching for non-existent Subscriptions"], ["https://github.com/aws-amplify/amplify-android/issues/1388", "Datastore model subscription fails due to timeout under slow network connection"], ["https://github.com/aws-amplify/amplify-js/issues/5173", "Sync processor does not follow @model subscriptions level"], ["https://github.com/aws-amplify/amplify-android/issues/483", "Subscription fails when following Getting Started doc steps"], ["https://github.com/aws-amplify/amplify-cli/issues/1810", "GraphQL AppSync Subscriptions not generated by AWS Amplify for custom mutations"], ["https://github.com/aws-amplify/amplify-js/issues/4683", "Authed subscriptions not working"], ["https://github.com/aws-amplify/amplify-js/issues/7318", "DataStore fails to initialize subscriptions when @auth directive with ownerField is used"], ["https://github.com/aws-amplify/amplify-js/issues/5050", "Limit of 50 subscriptions reached Datastore"], ["https://github.com/aws-amplify/amplify-js/issues/4811", "DataStore - authorization breaks sync"]]], [[0.5972421960008157, 0.5422511263620775, 0.5319638850060411, 0.5088615174130839, 0.4810881714816888, 0.46843560279402213, 0.46546206108789046, 0.4492849661278193, 0.4447436585509565, 0.42977467162614164]]]'

# %%
# with open('extra_tokens.txt', 'w') as f:
#     f.write(str(set(vocab2) - set(vocab)))

# %%
pw_mgr = query_df(js_df, number=5782)['bodyCleaned']
inspect_doc(pipe[0], pw_mgr)

# %%
js_issue = ['image file upload fail file size 5 mb']
pipe.predict(js_issue)

# %%
js_issue = ['additionalHeaders param is never passed to underlying function -- How do I access the current request headers or set them per request']
pred, score = pipe.predict(js_issue)
inspect_doc(pipe[0], query_df(small_df, repo='amplify-console', number=1519)['title_body'])
